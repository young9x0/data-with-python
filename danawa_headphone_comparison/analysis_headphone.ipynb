# %%
import pandas as pd
danawa_data = pd.read_excel('./danawa_data_preprocessing.xlsx')
danawa_data
# Out:
#     category company                     product   price  play_time  weight  \
# 0     유무선헤드폰    BOSE                  QC 울트라 헤드폰  459000       24.0   252.0
# 1      무선헤드폰   APPLE                      에어팟 맥스  653070       20.0   384.8
# 2     유무선헤드폰    SONY                  WH-1000XM5  397790       30.0   250.0
# 3     유무선헤드폰    SONY         ULT WEAR WH-ULT900N  233050       30.0   255.0
# 4     유무선헤드폰    젠하이저          모멘텀 4 와이어리스 M4AEBT  383860       60.0   293.0
# ..       ...     ...                         ...     ...        ...     ...
# 393   유무선헤드폰    젠하이저                  PXC 550 무선  561600        NaN   227.0
# 394   유무선헤드폰     몬스터  Elements Wireless Over-ear  551080       24.0     NaN
# 395   유무선헤드폰     몬스터    Elements Wireless On-ear  358300       24.0     NaN
# 396   유무선헤드폰     몬스터           Roc Sport Freedom  400720        NaN   220.0
# 397   유무선헤드폰      코시                 HS1372BT 뮤즈   54870        6.0   120.0
#
#      bluetooth_version
# 0                  5.3
# 1                  5.0
# 2                  5.2
# 3                  5.2
# 4                  5.2
# ..                 ...
# 393                4.2
# 394                4.0
# 395                4.0
# 396                NaN
# 397                3.0
#
# [398 rows x 7 columns]

# %%
top_list = danawa_data.sort_values(['play_time','bluetooth_version'],ascending=False)
top_list

# %%
play_time_mean = danawa_data['play_time'].mean()
weight_mean = danawa_data['weight'].mean()
bluetooth_version_mean = danawa_data['bluetooth_version'].mean()
price_mean = danawa_data['price'].mean()
play_time_mean
# Out:
# np.float64(28.509383378016086)

# %%
# condition_data = danawa_data[
#   (danawa_data['price'] <= price_mean) &
#   (danawa_data['play_time'] >= play_time_mean) &
#   (danawa_data['weight'] <= weight_mean) &
#   (danawa_data['bluetooth_version'] >= bluetooth_version_mean)
# ]
# condition_data
# Out:
#     category  company                          product   price  play_time  \
# 7     유무선헤드폰    Britz              브리츠인터내셔널 BT4000 ANC   86900       29.0
# 9     유무선헤드폰     SONY                        WH-CH720N  166480       35.0
# 11     무선헤드폰     젠하이저                       엑센텀 ACAEBT  184880       50.0
# 16    유무선헤드폰       마샬                         Major IV   79120       80.0
# 27    유무선헤드폰    Britz            브리츠인터내셔널 W800BT Qplus   43450       50.0
# 30     무선헤드폰     SONY                         WH-CH520   78260       50.0
# 32    유무선헤드폰       벨킨        사운드폼 미니 어린이 무선 헤드폰 AUD002   29900       30.0
# 40    유무선헤드폰    Britz                  브리츠인터내셔널 BT3000   49500       30.0
# 41     무선헤드폰    Britz                  브리츠인터내셔널 BT3500   46800       40.0
# 43     무선헤드폰      QCY                               H2   14370       60.0
# 55    유무선헤드폰    에디파이어                      W820NB Plus   62590       33.0
# 68     무선헤드폰     SONY                         WH-CH510   58650       35.0
# 72    유무선헤드폰    베이스어스                          D02 Pro   10890       40.0
# 76     무선헤드폰      JBL                          JR310BT   48413       30.0
# 78     무선헤드폰      JBL                       TUNE 510BT   50070       40.0
# 79    유무선헤드폰     SONY                        WH-CH710N  134390       35.0
# 88    유무선헤드폰  오디오테크니카                       ATH-S220BT   52960       60.0
# 89    유무선헤드폰      JBL                       TUNE 770NC  135710       44.0
# 90    유무선헤드폰  오디오테크니카                       ATH-M20xBT   90250       60.0
# 92    유무선헤드폰    베이스어스                        Bowie D05   36900       70.0
# 101   유무선헤드폰      JBL                       TUNE 720BT   70300       76.0
# 106    무선헤드폰  오디오테크니카                       ATH-SR30BT   86780       70.0
# 112   유무선헤드폰    베이스어스                        Bowie H1i   25900       70.0
# 118   유무선헤드폰      JBL                       TUNE 760NC   76250       35.0
# 124   유무선헤드폰      JBL                       TUNE 660NC   82071       44.0
# 132   유무선헤드폰      JBL                       LIVE 670NC  173900       50.0
# 141   유무선헤드폰      JBL                       TUNE 670NC   91150       44.0
# 150   유무선헤드폰       엔더                           아이언 맥스   29800       58.0
# 155   유무선헤드폰    Actto                       아우라 BTH-12   25610       40.0
# 158   유무선헤드폰       벨킨  디즈니 사운드폼 미니 어린이 무선 헤드폰 AUD002qc   59000       30.0
# 160   유무선헤드폰      디알고                          BHANC08   42000       32.0
# 166    무선헤드폰      피아톤                   보노비츠 라이트 BN300   66410       30.0
# 190    무선헤드폰      노키아                          WHP-101   38900       62.0
# 192   유무선헤드폰      SKY                       핏 H2 IM-H2   28400       30.0
# 204    무선헤드폰    베이스어스                      Bass 35 Max   34900       50.0
# 217    무선헤드폰      SKY                        핏 ANC H11   49900       36.0
# 224   유무선헤드폰    Picun                            B-01S   22670       46.0
# 244    무선헤드폰      자브라                          엘리트 45h  137810       50.0
# 284    무선헤드폰  Bluedio                               TM   12900       30.0
# 295   유무선헤드폰     HOCO                          W35 Air   17200       45.0
# 298    무선헤드폰     MPOW                         059 Lite   36900       60.0
# 301   유무선헤드폰     스컬캔디                         Hesh Evo  133000       36.0
# 340    무선헤드폰       코시                      헤이 HS2218BT   26700       35.0
# 342    무선헤드폰   Mackie                          MC-50BT  152200       34.0
# 343   유무선헤드폰    SIBYL                            TM-50   36210       35.0
# 360   유무선헤드폰      JBL                       TUNE 710BT  145600       50.0
#
#      weight  bluetooth_version
# 7     220.6                5.0
# 9     192.0                5.2
# 11    222.0                5.2
# 16    165.0                5.0
# 27    200.0                5.0
# 30    147.0                5.2
# 32    136.0                5.0
# 40    168.0                5.1
# 41    172.0                5.2
# 43    228.0                5.3
# 55    220.0                5.2
# 68    132.0                5.0
# 72    190.0                5.0
# 76    115.0                5.0
# 78    160.0                5.0
# 79    223.0                5.0
# 88    180.0                5.0
# 89    232.0                5.2
# 90    216.0                5.0
# 92    209.0                5.3
# 101   220.0                5.3
# 106   190.0                5.0
# 112   226.0                5.3
# 118   220.0                5.0
# 124   166.0                5.0
# 132   219.0                5.3
# 141   174.0                5.3
# 150   200.0                5.3
# 155   198.0                5.3
# 158   136.0                5.0
# 160   224.0                5.3
# 166   148.0                5.3
# 190   199.0                5.0
# 192   190.0                5.1
# 204   234.5                5.3
# 217   203.0                5.3
# 224   188.0                5.3
# 244   160.0                5.0
# 284   220.0                5.0
# 295   193.0                5.3
# 298   217.0                5.0
# 301   213.0                5.0
# 340   137.0                5.3
# 342   200.0                5.0
# 343   168.0                5.2
# 360   220.0                5.0

# %%
# condition_data = danawa_data[
#   (danawa_data['price'] <= price_mean) &
#   (danawa_data['play_time'] >= play_time_mean)
#   ]
# condition_data

# %%
condition_data = danawa_data[
  (danawa_data['price'] <= price_mean) &
  (danawa_data['play_time'] >= play_time_mean) &
  (danawa_data['weight'] <= weight_mean)
  ]
condition_data
# Out:
#     category  company                          product   price  play_time  \
# 7     유무선헤드폰    Britz              브리츠인터내셔널 BT4000 ANC   86900       29.0
# 9     유무선헤드폰     SONY                        WH-CH720N  166480       35.0
# 11     무선헤드폰     젠하이저                       엑센텀 ACAEBT  184880       50.0
# 16    유무선헤드폰       마샬                         Major IV   79120       80.0
# 27    유무선헤드폰    Britz            브리츠인터내셔널 W800BT Qplus   43450       50.0
# 30     무선헤드폰     SONY                         WH-CH520   78260       50.0
# 32    유무선헤드폰       벨킨        사운드폼 미니 어린이 무선 헤드폰 AUD002   29900       30.0
# 35    유무선헤드폰       마샬                          Major V  190000      100.0
# 40    유무선헤드폰    Britz                  브리츠인터내셔널 BT3000   49500       30.0
# 41     무선헤드폰    Britz                  브리츠인터내셔널 BT3500   46800       40.0
# 43     무선헤드폰      QCY                               H2   14370       60.0
# 55    유무선헤드폰    에디파이어                      W820NB Plus   62590       33.0
# 68     무선헤드폰     SONY                         WH-CH510   58650       35.0
# 72    유무선헤드폰    베이스어스                          D02 Pro   10890       40.0
# 76     무선헤드폰      JBL                          JR310BT   48413       30.0
# 78     무선헤드폰      JBL                       TUNE 510BT   50070       40.0
# 79    유무선헤드폰     SONY                        WH-CH710N  134390       35.0
# 88    유무선헤드폰  오디오테크니카                       ATH-S220BT   52960       60.0
# 89    유무선헤드폰      JBL                       TUNE 770NC  135710       44.0
# 90    유무선헤드폰  오디오테크니카                       ATH-M20xBT   90250       60.0
# 92    유무선헤드폰    베이스어스                        Bowie D05   36900       70.0
# 101   유무선헤드폰      JBL                       TUNE 720BT   70300       76.0
# 106    무선헤드폰  오디오테크니카                       ATH-SR30BT   86780       70.0
# 112   유무선헤드폰    베이스어스                        Bowie H1i   25900       70.0
# 118   유무선헤드폰      JBL                       TUNE 760NC   76250       35.0
# 124   유무선헤드폰      JBL                       TUNE 660NC   82071       44.0
# 132   유무선헤드폰      JBL                       LIVE 670NC  173900       50.0
# 141   유무선헤드폰      JBL                       TUNE 670NC   91150       44.0
# 150   유무선헤드폰       엔더                           아이언 맥스   29800       58.0
# 155   유무선헤드폰    Actto                       아우라 BTH-12   25610       40.0
# 158   유무선헤드폰       벨킨  디즈니 사운드폼 미니 어린이 무선 헤드폰 AUD002qc   59000       30.0
# 160   유무선헤드폰      디알고                          BHANC08   42000       32.0
# 166    무선헤드폰      피아톤                   보노비츠 라이트 BN300   66410       30.0
# 173   유무선헤드폰    Britz                  브리츠인터내셔널 W800BT   68900       35.0
# 190    무선헤드폰      노키아                          WHP-101   38900       62.0
# 192   유무선헤드폰      SKY                       핏 H2 IM-H2   28400       30.0
# 204    무선헤드폰    베이스어스                      Bass 35 Max   34900       50.0
# 217    무선헤드폰      SKY                        핏 ANC H11   49900       36.0
# 224   유무선헤드폰    Picun                            B-01S   22670       46.0
# 244    무선헤드폰      자브라                          엘리트 45h  137810       50.0
# 258   유무선헤드폰     SONY                         WH-XB700  188000       30.0
# 277    무선헤드폰      라플루                            AH-01   69000       70.0
# 284    무선헤드폰  Bluedio                               TM   12900       30.0
# 295   유무선헤드폰     HOCO                          W35 Air   17200       45.0
# 298    무선헤드폰     MPOW                         059 Lite   36900       60.0
# 301   유무선헤드폰     스컬캔디                         Hesh Evo  133000       36.0
# 340    무선헤드폰       코시                      헤이 HS2218BT   26700       35.0
# 342    무선헤드폰   Mackie                          MC-50BT  152200       34.0
# 343   유무선헤드폰    SIBYL                            TM-50   36210       35.0
# 360   유무선헤드폰      JBL                       TUNE 710BT  145600       50.0
# 366   유무선헤드폰    어반이어스                          플라탄2 BT   56170       30.0
# 376   유무선헤드폰   archon                      Freebuds E9   19900       50.0
#
#      weight  bluetooth_version
# 7     220.6                5.0
# 9     192.0                5.2
# 11    222.0                5.2
# 16    165.0                5.0
# 27    200.0                5.0
# 30    147.0                5.2
# 32    136.0                5.0
# 35    186.0                NaN
# 40    168.0                5.1
# 41    172.0                5.2
# 43    228.0                5.3
# 55    220.0                5.2
# 68    132.0                5.0
# 72    190.0                5.0
# 76    115.0                5.0
# 78    160.0                5.0
# 79    223.0                5.0
# 88    180.0                5.0
# 89    232.0                5.2
# 90    216.0                5.0
# 92    209.0                5.3
# 101   220.0                5.3
# 106   190.0                5.0
# 112   226.0                5.3
# 118   220.0                5.0
# 124   166.0                5.0
# 132   219.0                5.3
# 141   174.0                5.3
# 150   200.0                5.3
# 155   198.0                5.3
# 158   136.0                5.0
# 160   224.0                5.3
# 166   148.0                5.3
# 173   200.0                4.0
# 190   199.0                5.0
# 192   190.0                5.1
# 204   234.5                5.3
# 217   203.0                5.3
# 224   188.0                5.3
# 244   160.0                5.0
# 258   195.0                4.2
# 277   230.0                NaN
# 284   220.0                5.0
# 295   193.0                5.3
# 298   217.0                5.0
# 301   213.0                5.0
# 340   137.0                5.3
# 342   200.0                5.0
# 343   168.0                5.2
# 360   220.0                5.0
# 366   145.0                NaN
# 376   232.0                4.1

# %%
from hangul_font import to_hangul_font
import matplotlib.pyplot as plt
import seaborn as sns

to_hangul_font()

# %%
chart_data = danawa_data.dropna(axis=0)
len(chart_data)
chart_data['weight'] = chart_data.loc[:,'weight']/10
# chart_data.head()
# Out:
# /var/folders/_t/63z5k9h556n_zpkpl_ft10440000gn/T/ipykernel_1779/3849547612.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chart_data['weight'] = chart_data.loc[:,'weight']/10

# %%
play_time_max = chart_data['play_time'].max()
play_time_mean = chart_data['play_time'].mean()
weight_max = chart_data['weight'].max()
weight_mean = chart_data['weight'].mean()
print(play_time_max,play_time_mean)
print(weight_max,weight_mean)

plt.figure(figsize=(30,10))
plt.title("유무선 헤드폰 성능 차트(재생시간, 무게, 가격 기준)")
sns.scatterplot(x="play_time",y="weight",size="price",hue=chart_data['company'], data=chart_data, sizes=(10,1000),legend=False)
plt.plot([0,play_time_max],
         [play_time_mean,play_time_mean],
         'r--',
         lw=1,
         label="10g(표시 값이 30이라면 실제 무게는 300g)")
plt.plot([weight_mean,weight_mean],
         [0,weight_max],
         'b--',
         lw=1,
         label="시간")
plt.xlabel('재생시간')
plt.ylabel('무게')
plt.legend(loc="best",ncol=2)
plt.show()
# Out:
# 90.0 30.455555555555556
# 38.7 23.333814814814815

# %%
condition_data = condition_data.dropna(axis=0)
# condition_data['weight'] = condition_data.loc[:,'weight']
top_10_condition_data = condition_data[:10]
top_10_condition_data
# Out:
#    category company                    product   price  play_time  weight  \
# 7    유무선헤드폰   Britz        브리츠인터내셔널 BT4000 ANC   86900       29.0   220.6
# 9    유무선헤드폰    SONY                  WH-CH720N  166480       35.0   192.0
# 11    무선헤드폰    젠하이저                 엑센텀 ACAEBT  184880       50.0   222.0
# 16   유무선헤드폰      마샬                   Major IV   79120       80.0   165.0
# 27   유무선헤드폰   Britz      브리츠인터내셔널 W800BT Qplus   43450       50.0   200.0
# 30    무선헤드폰    SONY                   WH-CH520   78260       50.0   147.0
# 32   유무선헤드폰      벨킨  사운드폼 미니 어린이 무선 헤드폰 AUD002   29900       30.0   136.0
# 40   유무선헤드폰   Britz            브리츠인터내셔널 BT3000   49500       30.0   168.0
# 41    무선헤드폰   Britz            브리츠인터내셔널 BT3500   46800       40.0   172.0
# 43    무선헤드폰     QCY                         H2   14370       60.0   228.0
#
#     bluetooth_version
# 7                 5.0
# 9                 5.2
# 11                5.2
# 16                5.0
# 27                5.0
# 30                5.2
# 32                5.0
# 40                5.1
# 41                5.2
# 43                5.3

# %%
play_time_max = top_10_condition_data['play_time'].max()
play_time_mean = top_10_condition_data['play_time'].mean()
weight_max = top_10_condition_data['weight'].max()
weight_mean = top_10_condition_data['weight'].mean()

print(play_time_mean,weight_mean)
# Out:
# 45.4 185.06

# %%
plt.figure(figsize=(20,10))
plt.title("유무선 헤드폰 가성비 Top10(재생시간, 무게, 가격 평균 기준)")
sns.scatterplot(x="play_time",y="weight",size="price",hue=top_10_condition_data['company'],
                data=top_10_condition_data,sizes=(100,2000), legend=True)

for idx, row in top_10_condition_data.iterrows():
  x=row['play_time']
  y=row['weight']
  s=row['product']
  plt.text(x,y,s,size=10)
  
plt.xlabel('재생시간')
plt.ylabel('무게')
plt.legend(loc="best",ncol=2)
plt.show()
